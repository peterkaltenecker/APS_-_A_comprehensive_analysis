# %%
# to silence NumbaDeprecationWarning
import warnings
warnings.filterwarnings("ignore", message=".*The 'nopython' keyword.*")

# although, check for the actual reason for the warning (saved links), and update if the problem is solved !!!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import umap
import umap.plot

# %% [markdown]
# ### Data import

# %%
df_APS = pd.read_csv('C:/Adatok/SzKK/Emese csoportja/Greti anyaga/corrected final data/final_table_20240110.csv', sep=';', encoding="ISO-8859-1")

# %% [markdown]
# ### Dimensionality reduction

# %%
# selection of only the disease data
diseaseOnly = df_APS.copy()
diseaseOnly = diseaseOnly.iloc[:, 6:34]

# %%
# dimensionality reduction with UMAP
mapper = umap.UMAP(n_neighbors=15, 
                   min_dist=0.2, 
                   metric='manhattan', 
                   random_state=4347).fit(diseaseOnly)

# %% [markdown]
# ### Data visualization

# %% [markdown]
# #### 1. Main figure

# %% [markdown]
# For the proper visualization, some information is rearranged into single columns.

# %% [markdown]
# - Renaming some values

# %%
# to rename HT and GD for the figure legend
HTGD = df_APS.copy()   # to preserv original information in the df
HTGD = HTGD[['hashimoto', 'basedow']]

diseaseHT = {0:'other', 1:'HT'}
HTGD.replace({'hashimoto':diseaseHT}, inplace=True)

diseaseGD = {0:'other', 1:'GD'}
HTGD.replace({'basedow':diseaseGD}, inplace=True)

# %% [markdown]
# - Collecting the most frequent disease info into one column

# %%
# to collect all disease combinations
dis_comb_list = []

for i in range(len(diseaseOnly.index)):
    dis_inst = diseaseOnly.iloc[i,:]   
    dis_combs = str(dis_inst[dis_inst == 1].index)
    dis_combs = dis_combs.replace("'", "")
    dis_combs = dis_combs[6:-15]
    dis_comb_list.append(dis_combs)

# %%
dis_comb_list
# Out:
# ['[hashimoto, diabetes_mellitus_1]',
#  '[hashimoto, crohn]',
#  '[hashimoto, vitiligo]',
#  '[hashimoto, diabetes_mellitus_1, vitiligo]',
#  '[basedow, diabetes_mellitus_1]',
#  '[diabetes_mellitus_1, coeliakia]',
#  '[basedow, RA]',
#  '[hashimoto, early_gonadal_insufficiency, sjögren]',
#  '[hashimoto, primer_biliaris_cholangitis]',
#  '[hashimoto, diabetes_mellitus_1, hepatitis]',
#  '[hashimoto, early_gonadal_insufficiency]',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[diabetes_mellitus_1, hepatitis, sclerosing_cholangitis]',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[hashimoto, polymyositis]',
#  '[hashimoto, vitiligo, polymyositis]',
#  '[basedow, sclerosis_multiplex]',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[hashimoto, early_gonadal_insufficiency]',
#  '[early_gonadal_insufficiency, psoriasis]',
#  '[hashimoto, sjögren]',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[basedow, primer_biliaris_cholangitis]',
#  '[diabetes_mellitus_1, psoriasis]',
#  '[hashimoto, polymyositis]',
#  '[hashimoto, diabetes_mellitus_1, coeliakia]',
#  '[hashimoto, hepatitis]',
#  '[hashimoto, autoimmun_gastritis, diabetes_mellitus_1, coeliakia]',
#  '[hashimoto, SLE]',
#  '[hashimoto, psoriasis]',
#  '[basedow, coeliakia]',
#  '[adrenal, hashimoto, diabetes_mellitus_1]',
#  '[diabetes_mellitus_1, colitis_ulcerosa]',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[hashimoto, vitiligo]',
#  '[hashimoto, RA]',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[diabetes_mellitus_1, coeliakia]',
#  '[adrenal, hashimoto, early_gonadal_insufficiency]',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[basedow, RA]',
#  '[hashimoto, alopecia]',
#  '[basedow, crohn]',
#  '[basedow, autoimmun_gastritis, coeliakia]',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[hashimoto, autoimmun_gastritis]',
#  '[hashimoto, autoimmun_gastritis, diabetes_mellitus_1, vitiligo]',
#  '[basedow, coeliakia]',
#  '[basedow, RA]',
#  '[hashimoto, autoimmun_gastritis]',
#  '[hashimoto, diabetes_mellitus_1, early_gonadal_insufficiency]',
#  '[hashimoto, early_gonadal_insufficiency]',
#  '[adrenal, hashimoto]',
#  '[adrenal, hashimoto]',
#  '[basedow, autoimmun_gastritis, diabetes_mellitus_1]',
#  '[basedow, diabetes_mellitus_1, coeliakia]',
#  '[hashimoto, systemic_sclerosis]',
#  '[basedow, diabetes_mellitus_1]',
#  '[basedow, diabetes_mellitus_1]',
#  '[basedow, crohn]',
#  '[hashimoto, RA]',
#  '[hashimoto, haemolyticus_anaemia, hepatitis]',
#  '[basedow, autoimmun_gastritis]',
#  '[hashimoto, autoimmun_gastritis, vitiligo]',
#  '[hashimoto, haemolyticus_anaemia]',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[hashimoto, RA]',
#  '[adrenal, hashimoto]',
#  '[hashimoto, RA]',
#  '[basedow, vitiligo]',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[basedow, coeliakia]',
#  '[adrenal, sclerosis_multiplex]',
#  '[hashimoto, early_gonadal_insufficiency, alopecia]',
#  '[basedow, primer_biliaris_cholangitis]',
#  '[hashimoto, autoimmun_gastritis]',
#  '[basedow, diabetes_mellitus_1]',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[basedow, autoimmun_gastritis]',
#  '[hashimoto, coeliakia]',
#  '[hashimoto, alopecia]',
#  '[adrenal, basedow]',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[hashimoto, crohn]',
#  '[hashimoto, autoimmun_gastritis, vitiligo]',
#  '[basedow, SLE]',
#  '[basedow, SLE]',
#  '[basedow, RA]',
#  '[basedow, colitis_ulcerosa, coeliakia, psoriasis]',
#  '[adrenal, basedow, vitiligo]',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[adrenal, hashimoto]',
#  '[basedow, autoimmun_gastritis, diabetes_mellitus_1]',
#  '[hashimoto, alopecia]',
#  '[hashimoto, coeliakia]',
#  '[hashimoto, coeliakia]',
#  '[hashimoto, hepatitis, sjögren, RA]',
#  '[hashimoto, early_gonadal_insufficiency, colitis_ulcerosa]',
#  '[autoimmun_gastritis, hypopara]',
#  '[hashimoto, coeliakia]',
#  '[adrenal, crohn]',
#  '[hashimoto, coeliakia]',
#  '[hashimoto, crohn]',
#  '[hashimoto, coeliakia]',
#  '[adrenal, basedow]',
#  '[hashimoto, RA]',
#  '[adrenal, hashimoto, diabetes_mellitus_1]',
#  '[hashimoto, psoriasis]',
#  '[basedow, myasthenia_gravis]',
#  '[hashimoto, autoimmun_gastritis, sjögren]',
#  '[basedow, diabetes_mellitus_1]',
#  '[hashimoto, colitis_ulcerosa, coeliakia, SLE]',
#  '[basedow, crohn]',
#  '[diabetes_mellitus_1, hepatitis]',
#  '[hashimoto, primer_biliaris_cholangitis]',
#  '[hashimoto, SLE]',
#  '[hashimoto, coeliakia]',
#  '[diabetes_mellitus_1, sjögren, alopecia]',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[hashimoto, autoimmun_gastritis, colitis_ulcerosa, sjögren]',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[hashimoto, SLE]',
#  '[hashimoto, vitiligo]',
#  '[basedow, diabetes_mellitus_1]',
#  '[hashimoto, psoriasis, primer_antiphospholipid]',
#  '[basedow, sjögren]',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[hashimoto, autoimmun_gastritis, coeliakia]',
#  '[hypopara, mucocutan_candidiasis]',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[hashimoto, coeliakia]',
#  '[adrenal, basedow, autoimmun_gastritis]',
#  '[hashimoto, RA]',
#  '[hashimoto, autoimmun_gastritis]',
#  '[hashimoto, psoriasis]',
#  '[hashimoto, coeliakia]',
#  '[hashimoto, autoimmun_gastritis]',
#  '[basedow, RA]',
#  '[adrenal, hashimoto, diabetes_mellitus_1]',
#  '[basedow, SLE]',
#  '[adrenal, hashimoto]',
#  '[basedow, diabetes_mellitus_1, RA]',
#  '[basedow, ITP]',
#  '[basedow, diabetes_mellitus_1, coeliakia]',
#  '[hashimoto, autoimmun_gastritis, SLE]',
#  '[hashimoto, colitis_ulcerosa]',
#  '[basedow, psoriasis]',
#  '[basedow, myasthenia_gravis]',
#  '[hashimoto, vitiligo]',
#  '[hashimoto, autoimmun_gastritis, coeliakia,\n       primer_antiphospholipid],\n    ',
#  '[basedow, sjögren, RA]',
#  '[basedow, coeliakia]',
#  '[hashimoto, vitiligo, alopecia]',
#  '[hashimoto, psoriasis]',
#  '[hashimoto, sjögren]',
#  '[adrenal, basedow, autoimmun_gastritis]',
#  '[basedow, colitis_ulcerosa]',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[adrenal, hashimoto]',
#  '[hashimoto, autoimmun_gastritis, haemolyticus_anaemia]',
#  '[basedow, colitis_ulcerosa, sclerosis_multiplex]',
#  '[hashimoto, sjögren]',
#  '[adrenal, autoimmun_gastritis, vitiligo]',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[basedow, RA]',
#  '[hashimoto, myasthenia_gravis]',
#  '[hashimoto, alopecia]',
#  '[basedow, vitiligo, myasthenia_gravis]',
#  '[basedow, vitiligo]',
#  '[hashimoto, vitiligo]',
#  '[hashimoto, crohn]',
#  '[adrenal, hashimoto, RA]',
#  '[basedow, RA]',
#  '[hashimoto, RA]',
#  '[adrenal, hashimoto]',
#  '[basedow, diabetes_mellitus_1]',
#  '[basedow, vitiligo]',
#  '[hashimoto, RA]',
#  '[basedow, RA]',
#  '[adrenal, basedow, RA]',
#  '[hashimoto, RA]',
#  '[adrenal, hashimoto]',
#  '[hashimoto, RA]',
#  '[hashimoto, coeliakia, sjögren]',
#  '[basedow, vitiligo]',
#  '[hashimoto, coeliakia]',
#  '[adrenal, hashimoto]',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[hashimoto, autoimmun_gastritis, coeliakia, sclerosis_multiplex]',
#  '[hashimoto, myasthenia_gravis]',
#  '[basedow, autoimmun_gastritis, crohn]',
#  '[hashimoto, hypophysitis]',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[hashimoto, RA]',
#  '[hashimoto, polymyositis]',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[hashimoto, vitiligo]',
#  '[hashimoto, SLE]',
#  '[hashimoto, vitiligo, psoriasis]',
#  '[adrenal, hashimoto, vitiligo]',
#  '[diabetes_mellitus_1, RA]',
#  '[basedow, diabetes_mellitus_1]',
#  '[basedow, coeliakia]',
#  '[adrenal, hashimoto, autoimmun_gastritis]',
#  '[hashimoto, colitis_ulcerosa]',
#  '[adrenal, SLE]',
#  '[hashimoto, vitiligo]',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[adrenal, basedow, autoimmun_gastritis]',
#  '[adrenal, vitiligo]',
#  '[basedow, vitiligo]',
#  '[basedow, coeliakia]',
#  '[hashimoto, coeliakia]',
#  '[hashimoto, colitis_ulcerosa]',
#  '[hashimoto, SLE]',
#  '[hashimoto, vitiligo, early_gonadal_insufficiency]',
#  '[hypopara, hypophysitis, colitis_ulcerosa,\n       sclerosing_cholangitis],\n    ',
#  '[hashimoto, vitiligo]',
#  '[hashimoto, coeliakia]',
#  '[hashimoto, coeliakia, sjögren]',
#  '[hashimoto, vitiligo]',
#  '[hashimoto, SLE]',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[basedow, colitis_ulcerosa]',
#  '[hashimoto, coeliakia]',
#  '[basedow, coeliakia]',
#  '[basedow, psoriasis]',
#  '[adrenal, hashimoto, sjögren]',
#  '[hashimoto, RA]',
#  '[hashimoto, alopecia]',
#  '[hashimoto, RA]',
#  '[hashimoto, psoriasis]',
#  '[hashimoto, RA]',
#  '[hashimoto, coeliakia]',
#  '[hashimoto, coeliakia]',
#  '[basedow, vitiligo]',
#  '[hashimoto, vitiligo]',
#  '[hashimoto, vitiligo]',
#  '[hashimoto, coeliakia]',
#  '[hashimoto, alopecia]',
#  '[adrenal, hashimoto]',
#  '[hashimoto, sclerosis_multiplex]',
#  '[hashimoto, SLE]',
#  '[basedow, coeliakia]',
#  '[adrenal, hashimoto]',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[basedow, crohn]',
#  '[basedow, coeliakia, psoriasis]',
#  '[hashimoto, primer_biliaris_cholangitis, coeliakia, sjögren]',
#  '[basedow, colitis_ulcerosa]',
#  '[basedow, coeliakia]',
#  '[hashimoto, sjögren]',
#  '[hashimoto, diabetes_mellitus_1, coeliakia]',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[hashimoto, autoimmun_gastritis, coeliakia]',
#  '[hashimoto, vitiligo]',
#  '[hashimoto, sjögren]',
#  '[basedow, primer_biliaris_cholangitis]',
#  '[basedow, systemic_sclerosis]',
#  '[hashimoto, systemic_sclerosis]',
#  '[basedow, coeliakia]',
#  '[hashimoto, RA]',
#  '[basedow, coeliakia]',
#  '[hashimoto, coeliakia]',
#  '[basedow, RA]',
#  '[hashimoto, vitiligo]',
#  '[basedow, diabetes_mellitus_1]',
#  '[adrenal, RA]',
#  '[hashimoto, RA]',
#  '[basedow, sjögren]',
#  '[basedow, RA]',
#  '[hashimoto, RA]',
#  '[hashimoto, colitis_ulcerosa]',
#  '[adrenal, basedow]',
#  '[diabetes_mellitus_1, coeliakia]',
#  '[basedow, diabetes_mellitus_1]',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[hashimoto, primer_biliaris_cholangitis, sjögren]',
#  '[adrenal, hashimoto]',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[basedow, SLE, myasthenia_gravis]',
#  '[hashimoto, coeliakia]',
#  '[hashimoto, sjögren]',
#  '[adrenal, basedow]',
#  '[hashimoto, coeliakia]',
#  '[autoimmun_gastritis, early_gonadal_insufficiency, crohn,\n       psoriasis],\n    ',
#  '[hashimoto, colitis_ulcerosa]',
#  '[adrenal, hashimoto, autoimmun_gastritis]',
#  '[basedow, diabetes_mellitus_1]',
#  '[adrenal, hashimoto]',
#  '[hashimoto, vitiligo, sjögren]',
#  '[basedow, sclerosis_multiplex]',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[hashimoto, SLE]',
#  '[hashimoto, alopecia]',
#  '[basedow, polymyositis]',
#  '[hashimoto, coeliakia]',
#  '[hashimoto, early_gonadal_insufficiency]',
#  '[hashimoto, diabetes_mellitus_1, psoriasis]',
#  '[hashimoto, alopecia]',
#  '[basedow, coeliakia]',
#  '[basedow, crohn]',
#  '[hashimoto, diabetes_mellitus_1, colitis_ulcerosa]',
#  '[hashimoto, vitiligo]',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[hashimoto, early_gonadal_insufficiency]',
#  '[hashimoto, diabetes_mellitus_1, coeliakia]',
#  '[basedow, autoimmun_gastritis]',
#  '[diabetes_mellitus_1, coeliakia]',
#  '[hashimoto, vitiligo]',
#  '[hashimoto, autoimmun_gastritis]',
#  '[hashimoto, crohn]',
#  '[hashimoto, psoriasis]',
#  '[basedow, RA]',
#  '[adrenal, hashimoto]',
#  '[hashimoto, sjögren]',
#  '[basedow, diabetes_mellitus_1, coeliakia]',
#  '[hashimoto, RA]',
#  '[basedow, crohn]',
#  '[hashimoto, coeliakia, sjögren, psoriasis]',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[basedow, diabetes_mellitus_1]',
#  '[hashimoto, coeliakia]',
#  '[diabetes_mellitus_1, coeliakia]',
#  '[adrenal, hashimoto]',
#  '[hashimoto, sjögren]',
#  '[adrenal, hashimoto]',
#  '[hashimoto, coeliakia]',
#  '[hashimoto, coeliakia]',
#  '[hashimoto, myasthenia_gravis]',
#  '[hashimoto, sjögren]',
#  '[hashimoto, coeliakia]',
#  '[hashimoto, autoimmun_gastritis]',
#  '[hashimoto, polymyositis]',
#  '[basedow, autoimmun_gastritis, coeliakia]',
#  '[basedow, vitiligo]',
#  '[hashimoto, coeliakia]',
#  '[adrenal, hashimoto]',
#  '[hashimoto, SLE]',
#  '[hashimoto, sjögren]',
#  '[hashimoto, hepatitis, coeliakia, SLE]',
#  '[basedow, autoimmun_gastritis, RA]',
#  '[hashimoto, primer_biliaris_cholangitis, coeliakia, sjögren]',
#  '[hashimoto, autoimmun_gastritis]',
#  '[basedow, SLE, myasthenia_gravis]',
#  '[basedow, RA]',
#  '[adrenal, hashimoto]',
#  '[hashimoto, vitiligo]',
#  '[hashimoto, hepatitis]',
#  '[hashimoto, coeliakia]',
#  '[hashimoto, systemic_sclerosis]',
#  '[hashimoto, hepatitis]',
#  '[hashimoto, vitiligo, coeliakia]',
#  '[hashimoto, coeliakia]',
#  '[hashimoto, RA]',
#  '[hashimoto, vitiligo]',
#  '[basedow, RA]',
#  '[basedow, coeliakia]',
#  '[hashimoto, autoimmun_gastritis]',
#  '[hashimoto, colitis_ulcerosa, SLE]',
#  '[hashimoto, coeliakia]',
#  '[basedow, RA]',
#  '[hashimoto, RA]',
#  '[hashimoto, coeliakia, psoriasis]',
#  '[hashimoto, autoimmun_gastritis]',
#  '[hashimoto, vitiligo]',
#  '[hashimoto, SLE]',
#  '[hashimoto, psoriasis]',
#  '[basedow, RA]',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[hashimoto, diabetes_mellitus_1, coeliakia]',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[hashimoto, coeliakia]',
#  '[hashimoto, autoimmun_gastritis]',
#  '[hashimoto, RA]',
#  '[hashimoto, SLE]',
#  '[hashimoto, RA]',
#  '[adrenal, hashimoto, early_gonadal_insufficiency]']

# %%
# to add the results to the df
df_APS['combinations'] = pd.Series(dis_comb_list)

# %%
# to select the most frequent disease combinations
# these combinations were found subsequently, see the ... .ipynb file
mfreq_comb_list = ['[hashimoto, diabetes_mellitus_1]', '[hashimoto, coeliakia]', '[hashimoto, RA]', '[adrenal, hashimoto]', 
                   '[hashimoto, vitiligo]', '[basedow, RA]', '[basedow, coeliakia]', '[basedow, diabetes_mellitus_1]', 
                   '[hashimoto, autoimmun_gastritis]', '[hashimoto, SLE]', '[hashimoto, sjögren]']

dis_comb_list_mfreq = []

for combination in dis_comb_list:
    if combination in mfreq_comb_list:
        dis_comb_list_mfreq.append(combination)
    else:
        dis_comb_list_mfreq.append('other')

# %%
dis_comb_list_mfreq
# Out:
# ['[hashimoto, diabetes_mellitus_1]',
#  'other',
#  '[hashimoto, vitiligo]',
#  'other',
#  '[basedow, diabetes_mellitus_1]',
#  'other',
#  '[basedow, RA]',
#  'other',
#  'other',
#  'other',
#  'other',
#  '[hashimoto, diabetes_mellitus_1]',
#  'other',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[hashimoto, diabetes_mellitus_1]',
#  'other',
#  'other',
#  'other',
#  '[hashimoto, diabetes_mellitus_1]',
#  'other',
#  'other',
#  '[hashimoto, sjögren]',
#  '[hashimoto, diabetes_mellitus_1]',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  '[hashimoto, SLE]',
#  'other',
#  '[basedow, coeliakia]',
#  'other',
#  'other',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[hashimoto, vitiligo]',
#  '[hashimoto, RA]',
#  '[hashimoto, diabetes_mellitus_1]',
#  'other',
#  'other',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[basedow, RA]',
#  'other',
#  'other',
#  'other',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[hashimoto, autoimmun_gastritis]',
#  'other',
#  '[basedow, coeliakia]',
#  '[basedow, RA]',
#  '[hashimoto, autoimmun_gastritis]',
#  'other',
#  'other',
#  '[adrenal, hashimoto]',
#  '[adrenal, hashimoto]',
#  'other',
#  'other',
#  'other',
#  '[basedow, diabetes_mellitus_1]',
#  '[basedow, diabetes_mellitus_1]',
#  'other',
#  '[hashimoto, RA]',
#  'other',
#  'other',
#  'other',
#  'other',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[hashimoto, RA]',
#  '[adrenal, hashimoto]',
#  '[hashimoto, RA]',
#  'other',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[basedow, coeliakia]',
#  'other',
#  'other',
#  'other',
#  '[hashimoto, autoimmun_gastritis]',
#  '[basedow, diabetes_mellitus_1]',
#  '[hashimoto, diabetes_mellitus_1]',
#  'other',
#  '[hashimoto, coeliakia]',
#  'other',
#  'other',
#  '[hashimoto, diabetes_mellitus_1]',
#  'other',
#  'other',
#  'other',
#  'other',
#  '[basedow, RA]',
#  'other',
#  'other',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[adrenal, hashimoto]',
#  'other',
#  'other',
#  '[hashimoto, coeliakia]',
#  '[hashimoto, coeliakia]',
#  'other',
#  'other',
#  'other',
#  '[hashimoto, coeliakia]',
#  'other',
#  '[hashimoto, coeliakia]',
#  'other',
#  '[hashimoto, coeliakia]',
#  'other',
#  '[hashimoto, RA]',
#  'other',
#  'other',
#  'other',
#  'other',
#  '[basedow, diabetes_mellitus_1]',
#  'other',
#  'other',
#  'other',
#  'other',
#  '[hashimoto, SLE]',
#  '[hashimoto, coeliakia]',
#  'other',
#  '[hashimoto, diabetes_mellitus_1]',
#  'other',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[hashimoto, SLE]',
#  '[hashimoto, vitiligo]',
#  '[basedow, diabetes_mellitus_1]',
#  'other',
#  'other',
#  '[hashimoto, diabetes_mellitus_1]',
#  'other',
#  'other',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[hashimoto, coeliakia]',
#  'other',
#  '[hashimoto, RA]',
#  '[hashimoto, autoimmun_gastritis]',
#  'other',
#  '[hashimoto, coeliakia]',
#  '[hashimoto, autoimmun_gastritis]',
#  '[basedow, RA]',
#  'other',
#  'other',
#  '[adrenal, hashimoto]',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  '[hashimoto, vitiligo]',
#  'other',
#  'other',
#  '[basedow, coeliakia]',
#  'other',
#  'other',
#  '[hashimoto, sjögren]',
#  'other',
#  'other',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[adrenal, hashimoto]',
#  'other',
#  'other',
#  '[hashimoto, sjögren]',
#  'other',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[basedow, RA]',
#  'other',
#  'other',
#  'other',
#  'other',
#  '[hashimoto, vitiligo]',
#  'other',
#  'other',
#  '[basedow, RA]',
#  '[hashimoto, RA]',
#  '[adrenal, hashimoto]',
#  '[basedow, diabetes_mellitus_1]',
#  'other',
#  '[hashimoto, RA]',
#  '[basedow, RA]',
#  'other',
#  '[hashimoto, RA]',
#  '[adrenal, hashimoto]',
#  '[hashimoto, RA]',
#  'other',
#  'other',
#  '[hashimoto, coeliakia]',
#  '[adrenal, hashimoto]',
#  '[hashimoto, diabetes_mellitus_1]',
#  'other',
#  'other',
#  'other',
#  'other',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[hashimoto, RA]',
#  'other',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[hashimoto, vitiligo]',
#  '[hashimoto, SLE]',
#  'other',
#  'other',
#  'other',
#  '[basedow, diabetes_mellitus_1]',
#  '[basedow, coeliakia]',
#  'other',
#  'other',
#  'other',
#  '[hashimoto, vitiligo]',
#  '[hashimoto, diabetes_mellitus_1]',
#  'other',
#  'other',
#  'other',
#  '[basedow, coeliakia]',
#  '[hashimoto, coeliakia]',
#  'other',
#  '[hashimoto, SLE]',
#  'other',
#  'other',
#  '[hashimoto, vitiligo]',
#  '[hashimoto, coeliakia]',
#  'other',
#  '[hashimoto, vitiligo]',
#  '[hashimoto, SLE]',
#  '[hashimoto, diabetes_mellitus_1]',
#  'other',
#  '[hashimoto, coeliakia]',
#  '[basedow, coeliakia]',
#  'other',
#  'other',
#  '[hashimoto, RA]',
#  'other',
#  '[hashimoto, RA]',
#  'other',
#  '[hashimoto, RA]',
#  '[hashimoto, coeliakia]',
#  '[hashimoto, coeliakia]',
#  'other',
#  '[hashimoto, vitiligo]',
#  '[hashimoto, vitiligo]',
#  '[hashimoto, coeliakia]',
#  'other',
#  '[adrenal, hashimoto]',
#  'other',
#  '[hashimoto, SLE]',
#  '[basedow, coeliakia]',
#  '[adrenal, hashimoto]',
#  '[hashimoto, diabetes_mellitus_1]',
#  'other',
#  'other',
#  'other',
#  'other',
#  '[basedow, coeliakia]',
#  '[hashimoto, sjögren]',
#  'other',
#  '[hashimoto, diabetes_mellitus_1]',
#  'other',
#  '[hashimoto, vitiligo]',
#  '[hashimoto, sjögren]',
#  'other',
#  'other',
#  'other',
#  '[basedow, coeliakia]',
#  '[hashimoto, RA]',
#  '[basedow, coeliakia]',
#  '[hashimoto, coeliakia]',
#  '[basedow, RA]',
#  '[hashimoto, vitiligo]',
#  '[basedow, diabetes_mellitus_1]',
#  'other',
#  '[hashimoto, RA]',
#  'other',
#  '[basedow, RA]',
#  '[hashimoto, RA]',
#  'other',
#  'other',
#  'other',
#  '[basedow, diabetes_mellitus_1]',
#  '[hashimoto, diabetes_mellitus_1]',
#  'other',
#  '[adrenal, hashimoto]',
#  '[hashimoto, diabetes_mellitus_1]',
#  'other',
#  '[hashimoto, coeliakia]',
#  '[hashimoto, sjögren]',
#  'other',
#  '[hashimoto, coeliakia]',
#  'other',
#  'other',
#  'other',
#  '[basedow, diabetes_mellitus_1]',
#  '[adrenal, hashimoto]',
#  'other',
#  'other',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[hashimoto, SLE]',
#  'other',
#  'other',
#  '[hashimoto, coeliakia]',
#  'other',
#  'other',
#  'other',
#  '[basedow, coeliakia]',
#  'other',
#  'other',
#  '[hashimoto, vitiligo]',
#  '[hashimoto, diabetes_mellitus_1]',
#  'other',
#  'other',
#  'other',
#  'other',
#  '[hashimoto, vitiligo]',
#  '[hashimoto, autoimmun_gastritis]',
#  'other',
#  'other',
#  '[basedow, RA]',
#  '[adrenal, hashimoto]',
#  '[hashimoto, sjögren]',
#  'other',
#  '[hashimoto, RA]',
#  'other',
#  'other',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[basedow, diabetes_mellitus_1]',
#  '[hashimoto, coeliakia]',
#  'other',
#  '[adrenal, hashimoto]',
#  '[hashimoto, sjögren]',
#  '[adrenal, hashimoto]',
#  '[hashimoto, coeliakia]',
#  '[hashimoto, coeliakia]',
#  'other',
#  '[hashimoto, sjögren]',
#  '[hashimoto, coeliakia]',
#  '[hashimoto, autoimmun_gastritis]',
#  'other',
#  'other',
#  'other',
#  '[hashimoto, coeliakia]',
#  '[adrenal, hashimoto]',
#  '[hashimoto, SLE]',
#  '[hashimoto, sjögren]',
#  'other',
#  'other',
#  'other',
#  '[hashimoto, autoimmun_gastritis]',
#  'other',
#  '[basedow, RA]',
#  '[adrenal, hashimoto]',
#  '[hashimoto, vitiligo]',
#  'other',
#  '[hashimoto, coeliakia]',
#  'other',
#  'other',
#  'other',
#  '[hashimoto, coeliakia]',
#  '[hashimoto, RA]',
#  '[hashimoto, vitiligo]',
#  '[basedow, RA]',
#  '[basedow, coeliakia]',
#  '[hashimoto, autoimmun_gastritis]',
#  'other',
#  '[hashimoto, coeliakia]',
#  '[basedow, RA]',
#  '[hashimoto, RA]',
#  'other',
#  '[hashimoto, autoimmun_gastritis]',
#  '[hashimoto, vitiligo]',
#  '[hashimoto, SLE]',
#  'other',
#  '[basedow, RA]',
#  '[hashimoto, diabetes_mellitus_1]',
#  'other',
#  '[hashimoto, diabetes_mellitus_1]',
#  '[hashimoto, coeliakia]',
#  '[hashimoto, autoimmun_gastritis]',
#  '[hashimoto, RA]',
#  '[hashimoto, SLE]',
#  '[hashimoto, RA]',
#  'other']

# %%
# to add the results to the df
df_APS['most_freq_combinations'] = pd.Series(dis_comb_list_mfreq)

# %% [markdown]
# - All APS category info into one column

# %%
APS_cats = df_APS.copy()
APS_cats = APS_cats.iloc[:, [36, 37, 38, 43]]
APS_cats.head()
# Out:
#    APS I.  APS II.  APS III.  APS IV.
# 0       0        0         1        0
# 1       0        0         1        0
# 2       0        0         1        0
# 3       0        0         1        0
# 4       0        0         1        0

# %%
# to collect all APS category info
APS_cat_list = []

for i in range(len(APS_cats.index)):
    APS_inst = APS_cats.iloc[i,:]
    APS_actual = str(APS_inst[APS_inst == 1].index)
    APS_actual = APS_actual[8:-20]
    APS_cat_list.append(APS_actual)

# %%
# to add the results to the df
df_APS['APS_category'] = pd.Series(APS_cat_list)

# %% [markdown]
# - All APS III subcategory info into one column

# %%
APSIII_cats = df_APS.copy()
APSIII_cats = APSIII_cats.iloc[:, 39:43]
APSIII_cats.head()
# Out:
#    APS III/a  APS III/b  APSIII/c  APS III/d
# 0          1          0         0          0
# 1          0          1         0          0
# 2          0          0         1          0
# 3          1          0         0          0
# 4          1          0         0          0

# %%
# to collect all APS III subcategory info
APSIII_cat_list = []

for i in range(len(APSIII_cats.index)):
    APSIII_inst = APSIII_cats.iloc[i,:]
    if APSIII_inst.sum() == 1:    # apart from APS III, the sum will be 0 with other categories
        APSIII_actual = str(APSIII_inst[APSIII_inst == 1].index)
        APSIII_actual = APSIII_actual[8:-19]
        APSIII_cat_list.append(APSIII_actual)
    else:
        APSIII_cat_list.append("other")

# %%
# to add the results to the df
df_APS['APSIII_category'] = pd.Series(APSIII_cat_list)

# %% [markdown]
# #### The actual figure

# %%
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(12,18))

cmap1 = {'other':'#a8a8a8', 'HT':'#cc2a36'}
umap.plot.points(mapper, labels=HTGD['hashimoto'], color_key=cmap1, ax=ax[0][0])
ax[0][0].set_title('Hashimoto\'s thyroiditis')
ax[0][0].set_xlabel('UMAP 1')
ax[0][0].set_ylabel('UMAP 2')

cmap2 = {'other':'#a8a8a8', 'GD':'#cc2a36'}
umap.plot.points(mapper, labels=HTGD['basedow'], color_key=cmap2, ax=ax[0][1])
ax[0][1].set_title('Grave\'s disease')
ax[0][1].set_xlabel('UMAP 1')
ax[0][1].set_ylabel('UMAP 2')

cmap3 = {'[hashimoto, diabetes_mellitus_1]':'#cc0000', 
          '[hashimoto, coeliakia]':'#ff8000', 
          '[hashimoto, RA]':'#ffcc33', 
          '[adrenal, hashimoto]':'#bfff00', 
          '[hashimoto, vitiligo]':'#00e600', 
          '[basedow, RA]':'#00ffbf', 
          '[basedow, coeliakia]':'#f83873',
          '[basedow, diabetes_mellitus_1]':'#3333ff', 
          '[hashimoto, autoimmun_gastritis]':'#a64dff', 
          '[hashimoto, SLE]':'#ff33cc', 
          '[hashimoto, sjögren]':'#00bfff', 
          'other':'#a8a8a8'}
umap.plot.points(mapper, labels=df_APS['most_freq_combinations'], color_key=cmap3, ax=ax[1][0], show_legend=False)
ax[1][0].set_title('The most frequent disease combinations')
ax[1][0].set_xlabel('UMAP 1')
ax[1][0].set_ylabel('UMAP 2')

cmap4 = {2:'#363b74', 3:'#fc913a', 4:'#43e8d8'}
umap.plot.points(mapper, labels=df_APS['assoc_disease_no'], color_key=cmap4, ax=ax[1][1])
ax[1][1].set_title('The number of associated diseases')
ax[1][1].set_xlabel('UMAP 1')
ax[1][1].set_ylabel('UMAP 2')

cmap5 = {'APS I':'#ae0001', 'APS II':'#ffbe4f', 'APS III':'#88d8b0', 'APS IV':'#673888'}
umap.plot.points(mapper, labels=df_APS['APS_category'], color_key=cmap5, ax=ax[2][0])
ax[2][0].set_title('APS categories')
ax[2][0].set_xlabel('UMAP 1')
ax[2][0].set_ylabel('UMAP 2')

cmap6 = {'APS III/a':'#ae0001', 'APS III/b':'#ffbe4f', 'APSIII/c':'#88d8b0', 'APS III/d':'#673888', 'other':'#a8a8a8'}
umap.plot.points(mapper, labels=df_APS['APSIII_category'], color_key=cmap6, ax=ax[2][1])
ax[2][1].set_title('APS III subcategories')
ax[2][1].set_xlabel('UMAP 1')
ax[2][1].set_ylabel('UMAP 2')

# text for C
fig.text(x=0.1295, y=0.6005, s='GD - RA', fontsize=8)
fig.text(x=0.18, y=0.5985, s='GD - T1D', fontsize=8)
fig.text(x=0.229, y=0.585, s='GD - CD', fontsize=8)
fig.text(x=0.15, y=0.405, s='HT - T1D', fontsize=8)
fig.text(x=0.345, y=0.515, s='HT - CD', fontsize=8)
fig.text(x=0.39, y=0.497, s='HT - SLE', fontsize=8)
fig.text(x=0.437, y=0.476, s='HT - RA', fontsize=8)
fig.text(x=0.3095, y=0.467, s='HT - SS', fontsize=8)
fig.text(x=0.303, y=0.447, s='HT - AIG', fontsize=8)
fig.text(x=0.33, y=0.418, s='HT - AD', fontsize=8)
fig.text(x=0.3945, y=0.449, s='HT - Vit', fontsize=8)

# for lettering the figure
fig.text(x=0.1, y=0.893, s='A', fontsize=25)
fig.text(x=0.1, y=0.62, s='C', fontsize=25)
fig.text(x=0.1, y=0.348, s='E', fontsize=25)
fig.text(x=0.521, y=0.893, s='B', fontsize=25)
fig.text(x=0.521, y=0.62, s='D', fontsize=25)
fig.text(x=0.521, y=0.348, s='F', fontsize=25)

#fig.savefig('UMAPs_APS.tiff', bbox_inches='tight', dpi=300)
#fig.savefig('UMAPs_APS.pdf', bbox_inches='tight', dpi=300)
# Out:
# Text(0.521, 0.348, 'F')

# %% [markdown]
# <br>

# %% [markdown]
# #### 2. Supplementary figure

# %% [markdown]
# As for the main figure, some information is changed or rearranged here as well for the visualization.

# %% [markdown]
# - Renaming some values

# %%
# to rename the rest of the most frequent diseases for the supplementary figure's legends
freq_diseases = ['diabetes_mellitus_1', 'coeliakia', 'RA', 'adrenal', 'vitiligo', 'autoimmun_gastritis', 'sjögren', 'SLE']
abbrevs = ['T1D', 'CD', 'RA', 'AD', 'Vit', 'AIG', 'SS', 'SLE']

SupDiseases = df_APS.copy()   # to preserv original info in the df
SupDiseases = SupDiseases[freq_diseases]

for index, i in enumerate(freq_diseases):
    legendDict = {0:'other', 1:abbrevs[index]}
    SupDiseases.replace({i:legendDict}, inplace=True)

# %%
# to rename the values for the figure legend
sexes = {1:'men', 2:'women'}

sexesData = df_APS.copy()   # to preserv original info in the df
sexesData = sexesData[['gender']]
sexesData.replace({'gender':sexes}, inplace=True)

# %% [markdown]
# - Separation of instances based on age (under or over 18)

# %%
# to create a list with age info
age_dist_18_list = []

for i in range(len(df_APS.index)):
    if df_APS['age_at_disease_onset'][i] == -1:
        age_dist_18_list.append('unknown')
    elif df_APS['age_at_disease_onset'][i] < 18:
        age_dist_18_list.append('under 18')
    else:
        age_dist_18_list.append('over 18')

# %%
# to add the results to the df
df_APS['age_distribution_18'] = pd.Series(age_dist_18_list)

# %% [markdown]
# #### The actual figure

# %%
fig, ax = plt.subplots(nrows=4, ncols=3, figsize=(21,29))

cmap1 = {'other':'#a8a8a8', 'T1D':'#cc2a36'}
umap.plot.points(mapper, labels=SupDiseases['diabetes_mellitus_1'], color_key=cmap1, ax=ax[0][0])
ax[0][0].set_title('Diabetes mellitus type 1')
ax[0][0].set_xlabel('UMAP 1')
ax[0][0].set_ylabel('UMAP 2')

cmap2 = {'other':'#a8a8a8', 'CD':'#cc2a36'}
umap.plot.points(mapper, labels=SupDiseases['coeliakia'], color_key=cmap2, ax=ax[0][1])
ax[0][1].set_title('Coeliac disease')
ax[0][1].set_xlabel('UMAP 1')
ax[0][1].set_ylabel('UMAP 2')

cmap3 = {'other':'#a8a8a8', 'RA':'#cc2a36'}
umap.plot.points(mapper, labels=SupDiseases['RA'], color_key=cmap3, ax=ax[0][2])
ax[0][2].set_title('Rheumatoid arthritis')
ax[0][2].set_xlabel('UMAP 1')
ax[0][2].set_ylabel('UMAP 2')

cmap4 = {'other':'#a8a8a8', 'AD':'#cc2a36'}
umap.plot.points(mapper, labels=SupDiseases['adrenal'], color_key=cmap4, ax=ax[1][0])
ax[1][0].set_title('Addison\'s disease')
ax[1][0].set_xlabel('UMAP 1')
ax[1][0].set_ylabel('UMAP 2')

cmap5 = {'other':'#a8a8a8', 'Vit':'#cc2a36'}
umap.plot.points(mapper, labels=SupDiseases['vitiligo'], color_key=cmap5, ax=ax[1][1])
ax[1][1].set_title('Vitiligo')
ax[1][1].set_xlabel('UMAP 1')
ax[1][1].set_ylabel('UMAP 2')

cmap6 = {'other':'#a8a8a8', 'AIG':'#cc2a36'}
umap.plot.points(mapper, labels=SupDiseases['autoimmun_gastritis'], color_key=cmap6, ax=ax[1][2])
ax[1][2].set_title('Autoimmun gastritis')
ax[1][2].set_xlabel('UMAP 1')
ax[1][2].set_ylabel('UMAP 2')

cmap7 = {'other':'#a8a8a8', 'SS':'#cc2a36'}
umap.plot.points(mapper, labels=SupDiseases['sjögren'], color_key=cmap7, ax=ax[2][0])
ax[2][0].set_title('Sjogren\'s syndrom')
ax[2][0].set_xlabel('UMAP 1')
ax[2][0].set_ylabel('UMAP 2')

cmap8 = {'other':'#a8a8a8', 'SLE':'#cc2a36'}
umap.plot.points(mapper, labels=SupDiseases['SLE'], color_key=cmap8, ax=ax[2][1])
ax[2][1].set_title('Systemic lupus erythematosus')
ax[2][1].set_xlabel('UMAP 1')
ax[2][1].set_ylabel('UMAP 2')

cmap9 = {'men':'#363b74', 'women':'#fc913a'}
umap.plot.points(mapper, labels=sexesData['gender'], color_key=cmap9, ax=ax[3][0])
ax[3][0].set_title('Sex distribution')
ax[3][0].set_xlabel('UMAP 1')
ax[3][0].set_ylabel('UMAP 2')

cmap10 = {'unknown':'#43e8d8', 'under 18':'#462966', 'over 18':'#67c24c'}
umap.plot.points(mapper, labels=df_APS['age_distribution_18'], color_key=cmap10, ax=ax[3][1])
ax[3][1].set_title('Age distribution')
ax[3][1].set_xlabel('UMAP 1')
ax[3][1].set_ylabel('UMAP 2')

ax[2][2].set_visible(False)
ax[3][2].set_visible(False)

# for lettering the figure
fig.text(x=0.11, y=0.888, s='A', fontsize=25)
fig.text(x=0.11, y=0.285, s='B', fontsize=25)
fig.text(x=0.383, y=0.285, s='C', fontsize=25)

#fig.savefig('Suppl_UMAPs_APS.tiff', bbox_inches='tight', dpi=300)
#fig.savefig('Suppl_UMAPs_APS.pdf', bbox_inches='tight', dpi=300)
